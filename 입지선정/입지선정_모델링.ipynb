# %% [markdown]
# # 물류센터 입지선정 - 최종 ver

# %%
import os
os.chdir(r"C:\Users\myhyu\OneDrive\Desktop\2024-2 BaF")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
#pip install pulp
import pulp

#pip install geopy
from geopy.distance import geodesic
import folium

# %% [markdown]
# ---

# %% [markdown]
# # 데이터셋
# 모두 2차 전처리까지 완료된 데이터셋
# - 상파울루 : SP
#     - 47134 rows
#
#
# - 바이아 : BA
#     - 3396 rows

# %% [markdown]
# ### 상파울루 - SP
# 상파울루의 면적은 서울의 약 2.5배
# 상파울루의 인구는 약 1,300만 명

# %%
df_sp = pd.read_csv('전처리2차_SP.csv')
df_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41107 entries, 0 to 41106
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       41107 non-null  object
#  1   order_status                   41107 non-null  object
#  2   customer_id                    41107 non-null  object
#  3   customer_unique_id             41107 non-null  object
#  4   customer_zip_code_prefix       41107 non-null  int64
#  5   customer_city                  41107 non-null  object
#  6   customer_state                 41107 non-null  object
#  7   geolocation_lat                41107 non-null  float64
#  8   geolocation_lng                41107 non-null  float64
#  9   order_purchase_timestamp       41107 non-null  object
#  10  order_approved_at              41101 non-null  object
#  11  order_delivered_carrier_date   40808 non-null  object
#  12  order_delivered_customer_date  40475 non-null  object
#  13  order_estimated_delivery_date  41107 non-null  object
#  14  time_difference_0              41101 non-null  object
#  15  time_difference_1              40803 non-null  object
#  16  time_difference_2              40474 non-null  object
#  17  time_difference_total          40475 non-null  object
# dtypes: float64(2), int64(1), object(15)
# memory usage: 5.6+ MB

# %%
# 중심 좌표 설정 (평균 위도, 경도)
latitude = df_sp['geolocation_lat'].mean()
longitude = df_sp['geolocation_lng'].mean()

# Folium 지도 생성
m_sp = folium.Map(location=[latitude, longitude], zoom_start=10)

# 고객 위치를 지도에 마커로 표시 (투명도 설정)
for index, row in df_sp.iterrows():
    folium.CircleMarker([row['geolocation_lat'], row['geolocation_lng']],
                        radius=3,
                        color='blue',
                        fill=True,
                        fill_opacity=0.5  # 투명도 설정 (0.0에서 1.0 사이 값)
                       ).add_to(m_sp)

# 지도를 HTML 파일로 저장
m_sp.save('sp_customer_map_outlierX.html')

# %%
coords_sp = df_sp[['geolocation_lat', 'geolocation_lng']].values

# %% [markdown]
# # K-means Clustering
# 1차 클러스터링 :5

# %%
# K=5
kmeans = KMeans(n_clusters=5, random_state=0)
df_sp['cluster'] = kmeans.fit_predict(coords_sp)
df_sp['cluster'].value_counts()
# Out:
# cluster
# 0    26407
# 3     7024
# 2     3398
# 1     2231
# 4     2047
# Name: count, dtype: int64

# %%
# 클러스터 중심 좌표 출력
cluster_centers = kmeans.cluster_centers_
print("클러스터 중심 좌표:")
for i, center in enumerate(cluster_centers):
    print(f"클러스터 {i}: 위도: {center[0]}, 경도: {center[1]}")
# Out:
# 클러스터 중심 좌표:
# 클러스터 0: 위도: -23.588587878712463, 경도: -46.624547099900404
# 클러스터 1: 위도: -21.71665804914388, 경도: -50.49214998731062
# 클러스터 2: 위도: -21.350336461341964, 경도: -48.36640231928193
# 클러스터 3: 위도: -22.919464357699315, 경도: -47.334611568987754
# 클러스터 4: 위도: -23.148800258124083, 경도: -45.60890783624817

# %%
dbi_combined = davies_bouldin_score(df_sp[['geolocation_lat', 'geolocation_lng']], df_sp['cluster'])
print(f"통합된 클러스터링 DBI: {dbi_combined}")
# Out:
# 통합된 클러스터링 DBI: 0.7197276982942069

# %%
# 클러스터 별 고객 좌표 및 수
clusters = df_sp['cluster'].unique()  # 모든 클러스터의 고유 값
coords_all_clusters = [df_sp[df_sp['cluster'] == cluster][['geolocation_lat', 'geolocation_lng']].values for cluster in clusters]

# %% [markdown]
# # MILP 최적화

# %%
# 각 클러스터의 고객 수
num_customers_per_cluster = [len(coords) for coords in coords_all_clusters]
num_centers = 5  # 물류센터 수

# 고객과 물류센터 간의 거리 계산 함수 (유클리드 거리)
def calculate_distance(customer_loc, center_loc):
    return np.linalg.norm(customer_loc - center_loc)

# 고객-센터 간 거리 행렬 생성
cost_matrix = []
for cluster_index, coords in enumerate(coords_all_clusters):
    cluster_costs = np.zeros((num_customers_per_cluster[cluster_index], num_centers))
    for customer_index in range(num_customers_per_cluster[cluster_index]):
        for center_index in range(num_centers):
            # 클러스터 센터 좌표를 이용한 거리 계산
            cluster_costs[customer_index][center_index] = calculate_distance(coords[customer_index], kmeans.cluster_centers_[center_index])
    cost_matrix.append(cluster_costs)

# MILP 문제 정의
problem = pulp.LpProblem("Fulfillment_Center_Location_Clustering", pulp.LpMinimize)

# %%
# 고객-센터 간 서비스 여부를 나타내는 이진 변수 x[i][k][j]
x = [
    [[pulp.LpVariable(f"x_{i}_{k}_{j}", cat='Binary') for j in range(num_centers)]
      for k in range(num_customers_per_cluster[i])]
    for i in range(len(clusters))
]

# 물류센터 설치 여부를 나타내는 이진 변수 y[j]
y = [pulp.LpVariable(f"y_{j}", cat='Binary') for j in range(num_centers)]

# 목적 함수: 총 배송 비용 최소화
problem += pulp.lpSum(cost_matrix[i][k][j] * x[i][k][j]
                      for i in range(len(clusters))
                      for j in range(num_centers)
                      for k in range(num_customers_per_cluster[i]))

# 제약 조건 1: 각 고객은 하나의 물류센터에서만 서비스 받아야 한다
for i in range(len(clusters)):
    for k in range(num_customers_per_cluster[i]):
        problem += pulp.lpSum(x[i][k][j] for j in range(num_centers)) == 1

# 제약 조건 2: 물류센터가 설치된 경우에만 고객이 해당 센터에서 서비스를 받을 수 있다
for j in range(num_centers):
    for i in range(len(clusters)):
        for k in range(num_customers_per_cluster[i]):
            problem += x[i][k][j] <= y[j]

# 제약 조건 3: 물류센터 용량 제한 (예시: 각 물류센터는 최대 20,000명의 고객 처리 가능)
capacity = 20000
for j in range(num_centers):
    problem += pulp.lpSum(x[i][k][j] for i in range(len(clusters)) for k in range(num_customers_per_cluster[i])) <= capacity * y[j]

# %%
# 최적화 문제 해결
problem.solve()

# 설치된 물류센터 출력
for j in range(num_centers):
    if pulp.value(y[j]) == 1:
        print(f"물류센터 {j} 설치됨.")
    else:
        print(f"물류센터 {j} 설치되지 않음.")

# 고객 할당 결과 출력
for i in range(len(clusters)):
    for k in range(num_customers_per_cluster[i]):
        for j in range(num_centers):
            if pulp.value(x[i][k][j]) == 1:
                print(f"클러스터 {i}의 고객 {k}는 물류센터 {j}에서 서비스를 받음.")
# Out:
# 물류센터 0 설치됨.
# 물류센터 1 설치됨.
# 물류센터 2 설치됨.
# 물류센터 3 설치됨.
# 물류센터 4 설치됨.
# 클러스터 0의 고객 0는 물류센터 0에서 서비스를 받음.
# 클러스터 0의 고객 1는 물류센터 0에서 서비스를 받음.
# 클러스터 0의 고객
 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1783는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1784는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1785는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1786는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1787는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1788는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1789는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1790는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1791는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1792는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1793는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1794는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1795는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1796는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1797는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1798는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1799는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1800는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1801는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1802는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1803는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1804는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1805는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1806는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1807는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1808는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1809는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1810는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1811는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1812는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1813는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1814는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1815는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1816는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1817는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1818는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1819는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1820는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1821는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1822는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1823는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1824는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1825는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1826는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1827는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1828는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1829는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1830는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1831는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1832는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1833는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1834는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1835는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1836는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1837는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1838는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1839는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1840는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1841는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1842는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1843는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1844는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1845는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1846는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1847는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1848는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1849는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1850는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1851는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1852는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1853는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1854는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1855는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1856는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1857는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1858는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1859는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1860는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1861는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1862는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1863는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1864는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1865는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1866는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1867는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1868는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1869는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1870는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1871는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1872는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1873는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1874는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1875는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1876는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1877는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1878는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1879는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1880는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1881는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1882는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1883는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1884는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1885는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1886는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1887는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1888는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1889는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1890는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1891는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1892는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1893는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1894는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1895는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1896는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1897는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1898는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1899는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1900는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1901는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1902는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1903는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1904는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1905는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1906는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1907는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1908는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1909는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1910는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1911는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1912는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1913는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1914는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1915는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1916는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1917는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1918는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1919는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1920는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1921는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1922는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1923는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1924는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1925는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1926는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1927는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1928는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1929는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1930는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1931는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1932는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1933는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1934는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1935는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1936는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1937는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1938는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1939는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1940는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1941는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1942는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1943는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1944는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1945는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1946는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1947는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1948는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1949는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1950는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1951는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1952는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1953는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1954는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1955는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1956는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1957는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1958는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1959는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1960는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1961는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1962는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1963는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1964는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1965는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1966는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1967는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1968는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1969는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1970는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1971는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1972는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1973는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1974는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1975는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1976는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1977는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1978는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1979는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1980는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1981는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1982는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1983는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1984는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1985는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1986는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1987는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1988는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1989는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1990는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1991는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1992는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1993는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1994는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1995는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1996는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1997는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1998는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 1999는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2000는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2001는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2002는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2003는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2004는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2005는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2006는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2007는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2008는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2009는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2010는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2011는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2012는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2013는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2014는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2015는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2016는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2017는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2018는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2019는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2020는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2021는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2022는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2023는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2024는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2025는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2026는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2027는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2028는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2029는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2030는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2031는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2032는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2033는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2034는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2035는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2036는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2037는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2038는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2039는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2040는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2041는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2042는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2043는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2044는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2045는 물류센터 4에서 서비스를 받음.
# 클러스터 4의 고객 2046는 물류센터 4에서 서비스를 받음.

# %% [markdown]
# # 입지선정 결과

# %%
# 지도의 중심 좌표 설정
latitude = df_sp['geolocation_lat'].mean()
longitude = df_sp['geolocation_lng'].mean()

# Folium 지도 생성
m = folium.Map(location=[latitude, longitude], zoom_start=12)

# 클러스터 색상 정의
colors = ['blue', 'green', 'orange', 'purple', 'red']  # cluster 0-4 색상 정의

# 고객 위치를 지도에 마커로 표시
for cluster_id in range(5):
    cluster_data = df_sp[df_sp['cluster'] == cluster_id]
    for index, row in cluster_data.iterrows():
        color = colors[cluster_id]
        folium.CircleMarker([row['geolocation_lat'], row['geolocation_lng']],
                            radius=3,
                            color=color,
                            fill=True).add_to(m)

# 클러스터 센터 표시
centers = []
for cluster_id in range(5):
    center = kmeans.cluster_centers_[cluster_id]
    folium.Marker([center[0], center[1]], popup=f'Center {cluster_id}',
                  icon=folium.Icon(color='black')).add_to(m)
    centers.append(center)

# 지도 출력 및 저장
m.save("sp_fulfillment_centers_final.html")

# %%
df_sp.to_csv('입지선정완료1_sp.csv', index=False)
